# %% [markdown]
# #Calculadora Básica
#
# Esse programa é uma calculadora que recebe valores e operações sequênciais do usuário. O código recebe um primeiro input de valor do usuário e em seguida, recebe a operação que o mesmo deseja realizar, podendo ser de adição, subtração, multiplicação, divisão, divisão inteira, resto, e potenciação. Por último, o programa recebe um segundo valor e retorna o resultado da operação. Em todas as etapas há verificação de valores válidos

# %%
#Apresentacao e input do primeiro valor
print('Vamos realizar uma operação matematica.')
valor1 = float(input('Digite o primeiro valor: '))

#Input da operação desejada
print('\nQual operacao deseja realizar?\n+  -> soma\n-  -> subtracao\n*  -> multiplicacao\n** -> potenciacao\n/  -> divisao\n// -> divisao inteira\n%  -> resto da divisao')

operacao = ''
while(operacao != '+' and operacao != '-' and operacao != '*' and operacao != '**' and operacao != '/' and operacao != '//' and operacao != '%'):
    operacao = input("Digite o simbolo da operacao: ")
    if (operacao != '+' and operacao != '-' and operacao != '*' and operacao != '**' and operacao != '/' and operacao != '//' and operacao != '%'):
        print('Erro. Digite uma operacao valida!')

#Input do segundo valor
valor2 = float(input('\nDigite o segundo valor: '))

#Verifica o tipo de operacao, retorna o valor final e pergunta se deseja prosseguir
if operacao == '+':
    total = valor1 + valor2
elif operacao == '-':
    total = valor1 - valor2
elif operacao == '*':
    total = valor1 * valor2
elif operacao == '**':
    total = valor1 ** valor2
elif operacao == '/':
    total = valor1 / valor2
elif operacao == '//':
    total = valor1 // valor2
else:
    total = valor1 % valor2

#Retorna o valor final
print(f'O resultado é: {total}')

#Pergunta se o usuario deseja realizar novos calculos
continuar = ''
while (continuar != 'S' and continuar != 's' and continuar != 'sim' and continuar != 'N' and continuar != 'n' and continuar != 'nao'):
    continuar = input('Deseja realizar nova operacao? [S] para SIM ou [N] para NAO: ')
    if (continuar != 'S' and continuar != 's' and continuar != 'sim' and continuar != 'N' and continuar != 'n' and continuar != 'nao'):
        print('Erro! Digite um valor valido.')

if (continuar == 'N' or continuar == 'n' or continuar == 'nao'):
    print('\nObrigado por calcular conosco! Até logo!')
#Pergunta se o usuario deseja prosseguir utilizando o ultimo valor calculado. Caso contrário, solicita um novo valor.
else:
    #Abertura do while para continuidade indefinida do programa
    while (continuar == 'S' or continuar == 's' or continuar == 'sim'):
        pross = 0
        while (pross != 'S' and pross != 's' and pross != 'sim' and pross != 'N' and pross != 'n' and pross != 'nao'):
            pross = input('\nDeseja prosseguir com o ultimo valor calculado? [S] para SIM ou [N] para NAO: ')
            if (pross != 'S' and pross != 's' and pross != 'sim' and pross != 'N' and pross != 'n' and pross != 'nao'):
                print('Erro! Digite um valor valido.')
        if (pross != 'S' or pross != 's' or pross != 'sim'):
            valor1 = total
        else:
            valor1 = float(input('\nDigite então o primeiro valor: '))

        #Solicita o tipo de operação
        print('\nQual operacao deseja realizar?\n+  -> soma\n-  -> subtracao\n*  -> multiplicacao\n** -> potenciacao\n/  -> divisao\n// -> divisao inteira\n%  -> resto da divisao')

        operacao = ''
        while(operacao != '+' and operacao != '-' and operacao != '*' and operacao != '**' and operacao != '/' and operacao != '//' and operacao != '%'):
            operacao = input("Digite o simbolo da operacao: ")
            if (operacao != '+' and operacao != '-' and operacao != '*' and operacao != '**' and operacao != '/' and operacao != '//' and operacao != '%'):
                print('Erro. Digite uma operacao valida!')

        #Input do segundo valor
        valor2 = float(input('\nDigite o segundo valor: '))

        #Verifica o tipo de operacao, retorna o valor final e pergunta se deseja prosseguir
        if operacao == '+':
            total = valor1 + valor2
        elif operacao == '-':
            total = valor1 - valor2
        elif operacao == '*':
            total = valor1 * valor2
        elif operacao == '**':
            total = valor1 ** valor2
        elif operacao == '/':
            total = valor1 / valor2
        elif operacao == '//':
            total = valor1 // valor2
        else:
            total = valor1 % valor2

        #Retorna o valor final
        print(f'O resultado é: {total}')

        #Pergunta ao usuário se ele deseja realizar nova operação
        continuar = input('Deseja realizar nova operacao? [S] para SIM ou [N] para NAO: ')
        while (continuar != 'S' and continuar != 's' and continuar != 'sim' and continuar != 'N' and continuar != 'n' and continuar != 'nao'):
            print('Erro! Digite um valor valido.')
            continuar = input('Deseja realizar nova operacao? [S] para SIM ou [N] para NAO: ')
        if (continuar == 'N' or continuar == 'n' or continuar == 'nao'):
            print('\nObrigado por calcular conosco! Até logo!')
